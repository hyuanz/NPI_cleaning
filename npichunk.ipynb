# %%
# pip install censusgeocode

# %%
import pandas as pd
import numpy as np
import censusgeocode as cg
import time
from datetime import datetime
import os

# %%
# Prepping the input data in chunks

keep_col = ['NPI','Entity Type Code','Provider Organization Name (Legal Business Name)',
            'Provider Last Name (Legal Name)', 'Provider First Name', 'Provider Middle Name',
            'Provider Name Prefix Text', 'Provider Name Suffix Text',
            'NPI Deactivation Reason Code','NPI Deactivation Date','NPI Reactivation Date',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']

# %% [markdown]
# 1. Prosthetics Case Management: 1744P3200X
# 2. Orthotic Fitter: 225000000X
# 3. Orthotist: 222Z00000X
# 4. Prosthetist: 224P00000X
# 5. Prosthetic/Orthotic Supplier:335E00000X

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['1744P3200X','225000000X','222Z00000X','224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# %%
# This defines the rows I want
def sub_rows(data):
    # ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'CA'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    #ac = data['NPI Deactivation Reason Code'].isna()
    all_together = st & ta  #ec && ac 
    sub = data[all_together]
    return sub

# %%
def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# %%
# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )
# Out:
# 2023-03-13 10:18:46.932071
# Grabbed iter 1 total sub n so far 325
# Grabbed iter 2 total sub n so far 563
# Grabbed iter 3 total sub n so far 823
# Grabbed iter 4 total sub n so far 1013
# Grabbed iter 5 total sub n so far 1196
# Grabbed iter 6 total sub n so far 1381
# Grabbed iter 7 total sub n so far 1525
# Grabbed iter 8 total sub n so far 1639
# 2023-03-13 10:20:54.377445

# %%
ph_tx = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)

# %%
ph_tx
# Out:
#              NPI Entity Type Code  \
# 0     1427033703                1
# 1     1184609844                1
# 2     1609834274                1
# 3     1821042219                1
# 4     1679513204                1
# ...          ...              ...
# 1634  1942865605                2
# 1635  1952609661                2
# 1636  1952765711                2
# 1637  1912339474                2
# 1638  1235835398                1
#
#      Provider Organization Name (Legal Business Name)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1634                                 ACTIVE LIFE, LLC
# 1635                                 ACTIVE LIFE, LLC
# 1636                                 ACTIVE LIFE, LLC
# 1637           ALEXANDER PROSTHETICS & ORTHOTICS, INC
# 1638                                              NaN
#
#      Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                          DELA ROSA             RUSSELL              ANDRADA
# 1                              PINTO               DAVID                 JOHN
# 2                            YAGDJIS             DIMITRI                PETER
# 3                          SCHAEPPER            JOHANNES                  NaN
# 4                             VITALE               SANDY                    L
# ...                              ...                 ...                  ...
# 1634                             NaN                 NaN                  NaN
# 1635                             NaN                 NaN                  NaN
# 1636                             NaN                 NaN                  NaN
# 1637                             NaN                 NaN                  NaN
# 1638                           MATHU               AIJAZ                  NaN
#
#      Provider Name Prefix Text Provider Name Suffix Text  \
# 0                          MR.                       NaN
# 1                          MR.                       NaN
# 2                          MR.                       NaN
# 3                          MR.                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 1634                       NaN                       NaN
# 1635                       NaN                       NaN
# 1636                       NaN                       NaN
# 1637                       NaN                       NaN
# 1638                       NaN                       NaN
#
#      Provider First Line Business Practice Location Address  \
# 0                                             4860 Y ST
# 1                                             4860 Y ST
# 2                                      16122 COVELLO ST
# 3                                       519 N SMITH AVE
# 4                                          130 REGIS ST
# ...                                                 ...
# 1634                           16008 KAMANA RD STE 202A
# 1635                              7910 FROST ST STE 320
# 1636                 1700 E CESAR E CHAVEZ AVE STE 3750
# 1637                                    660 E REGENT ST
# 1638                              12458 WASHINGTON BLVD
#
#      Provider Business Practice Location Address City Name  \
# 0                                            SACRAMENTO
# 1                                            SACRAMENTO
# 2                                              VAN NUYS
# 3                                                CORONA
# 4                                               TURLOCK
# ...                                                 ...
# 1634                                       APPLE VALLEY
# 1635                                          SAN DIEGO
# 1636                                        LOS ANGELES
# 1637                                          INGLEWOOD
# 1638                                           WHITTIER
#
#      Provider Business Practice Location Address State Name  \
# 0                                                    CA
# 1                                                    CA
# 2                                                    CA
# 3                                                    CA
# 4                                                    CA
# ...                                                 ...
# 1634                                                 CA
# 1635                                                 CA
# 1636                                                 CA
# 1637                                                 CA
# 1638                                                 CA
#
#      Provider Business Practice Location Address Postal Code  \
# 0                                             958172307
# 1                                             958172307
# 2                                             914062910
# 3                                             928806911
# 4                                             953821129
# ...                                                 ...
# 1634                                          923071376
# 1635                                              92123
# 1636                                              90033
# 1637                                          903011415
# 1638                                          906021005
#
#      Provider Business Practice Location Address Telephone Number  \
# 0                                            9167346732
# 1                                            9167346732
# 2                                            8189885414
# 3                                            9515820153
# 4                                            2096349021
# ...                                                 ...
# 1634                                         7605156311
# 1635                                         6194886196
# 1636                                         3233528319
# 1637                                         3106749179
# 1638                                         5629451111
#
#      NPI Deactivation Reason Code NPI Deactivation Date NPI Reactivation Date
# 0                             NaN                   NaN                   NaN
# 1                             NaN                   NaN                   NaN
# 2                             NaN                   NaN                   NaN
# 3                             NaN                   NaN                   NaN
# 4                             NaN                   NaN                   NaN
# ...                           ...                   ...                   ...
# 1634                          NaN                   NaN                   NaN
# 1635                          NaN                   NaN                   NaN
# 1636                          NaN                   NaN                   NaN
# 1637                          NaN                   NaN                   NaN
# 1638                          NaN                   NaN                   NaN
#
# [1639 rows x 16 columns]

# %%
end_str = [' STE', ' SUITE', ' BLDG', ' TOWER', ', #', ' UNIT',
           ' APT', ' BUILDING',',', '#']

# %%
def clean_add(address):
    add_new = address.upper()
    for su in end_str:
        sf = address.find(su)
        if sf > -1:
            add_new = add_new[0:sf]
    add_new = add_new.replace('.','')
    add_new = add_new.strip()
    return add_new

# %%
ph_tx['Zip5'] = ph_tx['Provider Business Practice Location Address Postal Code'].str[0:5]
ph_tx['Address'] = ph_tx['Provider First Line Business Practice Location Address'].apply(clean_add)
ph_tx.rename(columns={'Provider Business Practice Location Address City Name':'City',
                      'Provider Business Practice Location Address State Name':'State2'},
             inplace=True)

# %%
ph_tx
# Out:
#              NPI Entity Type Code  \
# 0     1427033703                1
# 1     1184609844                1
# 2     1609834274                1
# 3     1821042219                1
# 4     1679513204                1
# ...          ...              ...
# 1634  1942865605                2
# 1635  1952609661                2
# 1636  1952765711                2
# 1637  1912339474                2
# 1638  1235835398                1
#
#      Provider Organization Name (Legal Business Name)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1634                                 ACTIVE LIFE, LLC
# 1635                                 ACTIVE LIFE, LLC
# 1636                                 ACTIVE LIFE, LLC
# 1637           ALEXANDER PROSTHETICS & ORTHOTICS, INC
# 1638                                              NaN
#
#      Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                          DELA ROSA             RUSSELL              ANDRADA
# 1                              PINTO               DAVID                 JOHN
# 2                            YAGDJIS             DIMITRI                PETER
# 3                          SCHAEPPER            JOHANNES                  NaN
# 4                             VITALE               SANDY                    L
# ...                              ...                 ...                  ...
# 1634                             NaN                 NaN                  NaN
# 1635                             NaN                 NaN                  NaN
# 1636                             NaN                 NaN                  NaN
# 1637                             NaN                 NaN                  NaN
# 1638                           MATHU               AIJAZ                  NaN
#
#      Provider Name Prefix Text Provider Name Suffix Text  \
# 0                          MR.                       NaN
# 1                          MR.                       NaN
# 2                          MR.                       NaN
# 3                          MR.                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 1634                       NaN                       NaN
# 1635                       NaN                       NaN
# 1636                       NaN                       NaN
# 1637                       NaN                       NaN
# 1638                       NaN                       NaN
#
#      Provider First Line Business Practice Location Address          City  \
# 0                                             4860 Y ST        SACRAMENTO
# 1                                             4860 Y ST        SACRAMENTO
# 2                                      16122 COVELLO ST          VAN NUYS
# 3                                       519 N SMITH AVE            CORONA
# 4                                          130 REGIS ST           TURLOCK
# ...                                                 ...               ...
# 1634                           16008 KAMANA RD STE 202A      APPLE VALLEY
# 1635                              7910 FROST ST STE 320         SAN DIEGO
# 1636                 1700 E CESAR E CHAVEZ AVE STE 3750       LOS ANGELES
# 1637                                    660 E REGENT ST         INGLEWOOD
# 1638                              12458 WASHINGTON BLVD          WHITTIER
#
#      State2 Provider Business Practice Location Address Postal Code  \
# 0        CA                                          958172307
# 1        CA                                          958172307
# 2        CA                                          914062910
# 3        CA                                          928806911
# 4        CA                                          953821129
# ...     ...                                                ...
# 1634     CA                                          923071376
# 1635     CA                                              92123
# 1636     CA                                              90033
# 1637     CA                                          903011415
# 1638     CA                                          906021005
#
#      Provider Business Practice Location Address Telephone Number  \
# 0                                            9167346732
# 1                                            9167346732
# 2                                            8189885414
# 3                                            9515820153
# 4                                            2096349021
# ...                                                 ...
# 1634                                         7605156311
# 1635                                         6194886196
# 1636                                         3233528319
# 1637                                         3106749179
# 1638                                         5629451111
#
#      NPI Deactivation Reason Code NPI Deactivation Date NPI Reactivation Date  \
# 0                             NaN                   NaN                   NaN
# 1                             NaN                   NaN                   NaN
# 2                             NaN                   NaN                   NaN
# 3                             NaN                   NaN                   NaN
# 4                             NaN                   NaN                   NaN
# ...                           ...                   ...                   ...
# 1634                          NaN                   NaN                   NaN
# 1635                          NaN                   NaN                   NaN
# 1636                          NaN                   NaN                   NaN
# 1637                          NaN                   NaN                   NaN
# 1638                          NaN                   NaN                   NaN
#
#        Zip5                    Address
# 0     95817                  4860 Y ST
# 1     95817                  4860 Y ST
# 2     91406           16122 COVELLO ST
# 3     92880            519 N SMITH AVE
# 4     95382               130 REGIS ST
# ...     ...                        ...
# 1634  92307            16008 KAMANA RD
# 1635  92123              7910 FROST ST
# 1636  90033  1700 E CESAR E CHAVEZ AVE
# 1637  90301            660 E REGENT ST
# 1638  90602      12458 WASHINGTON BLVD
#
# [1639 rows x 18 columns]

# %%
def split_geo(df, add, city, state, zipcode, chunk_size=500):
    df_new = df.copy()
    df_new.reset_index(inplace=True)
    splits = np.ceil(df_new.shape[0]/chunk_size)
    chunk_li = np.array_split(df_new['index'], splits)
    res_li = []
    pick_fi = []
    for i,c in enumerate(chunk_li):
        # Grab data, export to csv
        sub_data = df_new.loc[c, ['index',add,city,state,zipcode]]
        sub_data.to_csv('temp_geo.csv',header=False,index=False)
        # Geo the results and turn back into df
        print(f'Geocoding round {int(i)+1} of {int(splits)}, {datetime.now()}')
        result = cg.addressbatch('temp_geo.csv') #should try/except?
        # May want to dump the intermediate results
        #pi_str = f'pickres_{int(i)}.p'
        #pickle.dump( favorite_color, open( pi_str, "wb" ) )
        #pick_fi.append(pi_str.copy())
        names = list(result[0].keys())
        res_zl = []
        for r in result:
            res_zl.append(list(r.values()))
        res_df = pd.DataFrame(res_zl, columns=names)
        res_li.append(res_df.copy())
        # time.sleep(10) #sleep 10 seconds to not get cutoff from request
    final_df = pd.concat(res_li)
    final_df.rename(columns={'id':'row'}, inplace=True)
    final_df.reset_index(inplace=True, drop=True)
    # Clean up csv file
    os.remove('temp_geo.csv')
    return final_df

# %%
geo_pharm = split_geo(ph_tx, add='Address', city='City', state='State2', zipcode='Zip5', chunk_size=500)
# Out:
# Geocoding round 1 of 4, 2023-03-13 10:21:07.268730
# Geocoding round 2 of 4, 2023-03-13 10:21:15.376580
# Geocoding round 3 of 4, 2023-03-13 10:21:25.250489
# Geocoding round 4 of 4, 2023-03-13 10:21:32.447006

# %%
print(geo_pharm['match'].value_counts())
# Out:
# True     1496
# False     143
# Name: match, dtype: int64

# %%
geo_pharm['rowN'] = geo_pharm['row'].astype(int)
gp2 = geo_pharm.sort_values(by='rowN').reset_index(drop=True)

# %%
kg = ['address','match','lat','lon']
kd = ['NPI',
      'Provider Organization Name (Legal Business Name)',
      'Provider Last Name (Legal Name)', 'Provider First Name', 'Provider Middle Name', 
      'Provider Name Prefix Text',
      'Provider First Line Business Practice Location Address',
      'Provider Business Practice Location Address Telephone Number',
      'Address','City','State2','Zip5']

final_pharm = pd.concat( [ph_tx[kd], gp2[kg]], axis=1 )

# %%
final_pharm
# Out:
#              NPI Provider Organization Name (Legal Business Name)  \
# 0     1427033703                                              NaN
# 1     1184609844                                              NaN
# 2     1609834274                                              NaN
# 3     1821042219                                              NaN
# 4     1679513204                                              NaN
# ...          ...                                              ...
# 1634  1942865605                                 ACTIVE LIFE, LLC
# 1635  1952609661                                 ACTIVE LIFE, LLC
# 1636  1952765711                                 ACTIVE LIFE, LLC
# 1637  1912339474           ALEXANDER PROSTHETICS & ORTHOTICS, INC
# 1638  1235835398                                              NaN
#
#      Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                          DELA ROSA             RUSSELL              ANDRADA
# 1                              PINTO               DAVID                 JOHN
# 2                            YAGDJIS             DIMITRI                PETER
# 3                          SCHAEPPER            JOHANNES                  NaN
# 4                             VITALE               SANDY                    L
# ...                              ...                 ...                  ...
# 1634                             NaN                 NaN                  NaN
# 1635                             NaN                 NaN                  NaN
# 1636                             NaN                 NaN                  NaN
# 1637                             NaN                 NaN                  NaN
# 1638                           MATHU               AIJAZ                  NaN
#
#      Provider Name Prefix Text  \
# 0                          MR.
# 1                          MR.
# 2                          MR.
# 3                          MR.
# 4                          NaN
# ...                        ...
# 1634                       NaN
# 1635                       NaN
# 1636                       NaN
# 1637                       NaN
# 1638                       NaN
#
#      Provider First Line Business Practice Location Address  \
# 0                                             4860 Y ST
# 1                                             4860 Y ST
# 2                                      16122 COVELLO ST
# 3                                       519 N SMITH AVE
# 4                                          130 REGIS ST
# ...                                                 ...
# 1634                           16008 KAMANA RD STE 202A
# 1635                              7910 FROST ST STE 320
# 1636                 1700 E CESAR E CHAVEZ AVE STE 3750
# 1637                                    660 E REGENT ST
# 1638                              12458 WASHINGTON BLVD
#
#      Provider Business Practice Location Address Telephone Number  \
# 0                                            9167346732
# 1                                            9167346732
# 2                                            8189885414
# 3                                            9515820153
# 4                                            2096349021
# ...                                                 ...
# 1634                                         7605156311
# 1635                                         6194886196
# 1636                                         3233528319
# 1637                                         3106749179
# 1638                                         5629451111
#
#                         Address          City State2   Zip5  \
# 0                     4860 Y ST    SACRAMENTO     CA  95817
# 1                     4860 Y ST    SACRAMENTO     CA  95817
# 2              16122 COVELLO ST      VAN NUYS     CA  91406
# 3               519 N SMITH AVE        CORONA     CA  92880
# 4                  130 REGIS ST       TURLOCK     CA  95382
# ...                         ...           ...    ...    ...
# 1634            16008 KAMANA RD  APPLE VALLEY     CA  92307
# 1635              7910 FROST ST     SAN DIEGO     CA  92123
# 1636  1700 E CESAR E CHAVEZ AVE   LOS ANGELES     CA  90033
# 1637            660 E REGENT ST     INGLEWOOD     CA  90301
# 1638      12458 WASHINGTON BLVD      WHITTIER     CA  90602
#
#                                                 address  match        lat  \
# 0                      4860 Y ST, SACRAMENTO, CA, 95817   True  38.552486
# 1                      4860 Y ST, SACRAMENTO, CA, 95817   True  38.552486
# 2                 16122 COVELLO ST, VAN NUYS, CA, 91406   True  34.207523
# 3                    519 N SMITH AVE, CORONA, CA, 92880   True  33.895226
# 4                      130 REGIS ST, TURLOCK, CA, 95382   True  37.519412
# ...                                                 ...    ...        ...
# 1634           16008 KAMANA RD, APPLE VALLEY, CA, 92307   True  34.542401
# 1635                7910 FROST ST, SAN DIEGO, CA, 92123   True  32.800261
# 1636  1700 E CESAR E CHAVEZ AVE, LOS ANGELES, CA, 90033   True  34.051144
# 1637              660 E REGENT ST, INGLEWOOD, CA, 90301   True  33.964526
# 1638         12458 WASHINGTON BLVD, WHITTIER, CA, 90602   True  33.967605
#
#              lon
# 0    -121.448804
# 1    -121.448804
# 2    -118.484261
# 3    -117.590408
# 4    -120.849607
# ...          ...
# 1634 -117.271759
# 1635 -117.154388
# 1636 -118.217488
# 1637 -118.344432
# 1638 -118.046286
#
# [1639 rows x 16 columns]

# %%
final_pharm.to_csv('clinics_Cali.csv',index=False)
