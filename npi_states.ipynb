# %%
import pandas as pd
import numpy as np
import censusgeocode as cg
import time
from datetime import datetime
import os

# %%
keep_col = ['NPI','Entity Type Code','Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number',
            'NPI Deactivation Reason Code']
# 'Provider Last Name (Legal Name)', 'Provider First Name', 'Provider Middle Name',
# 'Provider Name Prefix Text', 'Provider Name Suffix Text',
# 'NPI Deactivation Date','NPI Reactivation Date',

# %% [markdown]
# ### Arizona

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['222Z00000X', '224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# This defines the rows I want
def sub_rows(data):
    ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'AZ'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    ac = data['NPI Deactivation Reason Code'].isna()
    all_together = ec & st & ta & ac 
    sub = data[all_together]
    return sub

def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )

ph_tx_az = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)
ph_tx_az['Provider Business Practice Location Address Postal Code'] = ph_tx_az['Provider Business Practice Location Address Postal Code'].str[0:5]

ph_tx_az = ph_tx_az[['Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']]
ph_tx_az
# Out:
# 2023-03-27 09:19:53.560302
# Grabbed iter 1 total sub n so far 7
# Grabbed iter 2 total sub n so far 34
# Grabbed iter 3 total sub n so far 51
# Grabbed iter 4 total sub n so far 76
# Grabbed iter 5 total sub n so far 100
# Grabbed iter 6 total sub n so far 140
# Grabbed iter 7 total sub n so far 176
# Grabbed iter 8 total sub n so far 200
# 2023-03-27 09:21:53.495129
#     Provider Organization Name (Legal Business Name)  \
# 0                            PEDORTHIC SERVICES PLLC
# 1                              BEAS ENTERPRISES, INC
# 2                              TOWNSON'S PROSTHETICS
# 3                               GBL ENTERPRISES, LLC
# 4                    CUSTOM OCULAR PROSTHETICS, INC.
# ..                                               ...
# 195              NEVADA ORTHOTICS & PROSTHETICS, INC
# 196                    PRO AMERICAN MEDICAL SUPPLIES
# 197                       CRANIAL TECHNOLOGIES, INC.
# 198                          ARTISAN PROSTHETICS LLC
# 199                      ROADRUNNER PROSTHETICS INC.
#
#     Provider First Line Business Practice Location Address  \
# 0                                 3264 E SPEEDWAY BLVD
# 1                                13980 W BELL RD STE 7
# 2                                   3855 N. ORACLE RD.
# 3                                       5350 N 16TH ST
# 4                                   9465 E HARRISON PL
# ..                                                 ...
# 195                                1863 AIRFIED AVENUE
# 196                              2001 W ROSE GARDEN LN
# 197                            3591 S MERCY RD STE 201
# 198                                     4501 N 32ND ST
# 199                            42212 N 41ST DR STE 105
#
#     Provider Business Practice Location Address City Name  \
# 0                                               TUCSON
# 1                                             SURPRISE
# 2                                               TUCSON
# 3                                              PHOENIX
# 4                                               TUCSON
# ..                                                 ...
# 195                                            KINGMAN
# 196                                            PHOENIX
# 197                                            GILBERT
# 198                                            PHOENIX
# 199                                             ANTHEM
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   AZ
# 1                                                   AZ
# 2                                                   AZ
# 3                                                   AZ
# 4                                                   AZ
# ..                                                 ...
# 195                                                 AZ
# 196                                                 AZ
# 197                                                 AZ
# 198                                                 AZ
# 199                                                 AZ
#
#     Provider Business Practice Location Address Postal Code  \
# 0                                                85716
# 1                                                85374
# 2                                                85705
# 3                                                85016
# 4                                                85710
# ..                                                 ...
# 195                                              86401
# 196                                              85027
# 197                                              85297
# 198                                              85018
# 199                                              85086
#
#     Provider Business Practice Location Address Telephone Number
# 0                                           5203273166
# 1                                           6235841618
# 2                                           5208881334
# 3                                           6022349568
# 4                                           5207227471
# ..                                                 ...
# 195                                         9287183987
# 196                                         6024308647
# 197                                         8444475894
# 198                                         6026677827
# 199                                         6233524520
#
# [200 rows x 6 columns]

# %%
ph_tx_az[ph_tx_az['Provider Organization Name (Legal Business Name)'].str.contains("NORDSTROM")]
# Out:
#    Provider Organization Name (Legal Business Name)  \
# 49                     NORDSTROM INC & SUBSIDIARIES
# 50                     NORDSTROM INC & SUBSIDIARIES
#
#    Provider First Line Business Practice Location Address  \
# 49                                7055 E CAMELBACK RD
# 50                               3199 W CHANDLER BLVD
#
#    Provider Business Practice Location Address City Name  \
# 49                                         SCOTTSDALE
# 50                                           CHANDLER
#
#    Provider Business Practice Location Address State Name  \
# 49                                                 AZ
# 50                                                 AZ
#
#    Provider Business Practice Location Address Postal Code  \
# 49                                              85251
# 50                                              85226
#
#    Provider Business Practice Location Address Telephone Number
# 49                                         6029464111
# 50                                         4808552500

# %%
l = ph_tx_az[ph_tx_az['Provider Organization Name (Legal Business Name)'].str.contains("PROSTHETICS") & ph_tx_az['Provider Organization Name (Legal Business Name)'].str.contains("ORTHOTICS")]
len(l)
# Out:
# 59

# %% [markdown]
# ### Nevada

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['222Z00000X', '224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# This defines the rows I want
def sub_rows(data):
    ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'NV'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    ac = data['NPI Deactivation Reason Code'].isna()
    all_together = ec & st & ta & ac 
    sub = data[all_together]
    return sub

def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )

ph_tx_nv = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)
ph_tx_nv['Provider Business Practice Location Address Postal Code'] = ph_tx_nv['Provider Business Practice Location Address Postal Code'].str[0:5]

ph_tx_nv = ph_tx_nv[['Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']]
ph_tx_nv
# Out:
# 2023-03-27 09:32:42.088424
# Grabbed iter 1 total sub n so far 4
# Grabbed iter 2 total sub n so far 18
# Grabbed iter 3 total sub n so far 28
# Grabbed iter 4 total sub n so far 36
# Grabbed iter 5 total sub n so far 46
# Grabbed iter 6 total sub n so far 62
# Grabbed iter 7 total sub n so far 78
# Grabbed iter 8 total sub n so far 102
# 2023-03-27 09:34:44.631377
#     Provider Organization Name (Legal Business Name)  \
# 0                                     EMPICARE, INC.
# 1             M&M ORTHOTIC & PROSTHETIC CENTERS, LLC
# 2                      THERAPEUTIC MASSAGING INSOLES
# 3          HANGER PROSTHETICS & ORTHOTICS WEST, INC.
# 4                      ORTHOPRO OF CARSON CITY, INC.
# ..                                               ...
# 97                              JAMES J LYNCH MD LTD
# 98                             JAMES J LYNCH M D LTD
# 99                              JAMES J LYNCH MD LTD
# 100                              HURD INDUSTRIES LLC
# 101                               PLUS ME BRANDS LLC
#
#     Provider First Line Business Practice Location Address  \
# 0                                   880 SEVEN HILLS DR
# 1                                 3061 S MARYLAND PKWY
# 2                                         3280 WYNN RD
# 3                               6430 MEDICAL CENTER ST
# 4                                      415 W SOPHIA ST
# ..                                                 ...
# 97                              780 VISTA BLVD STE 100
# 98                           1470 MEDICAL PKWY STE 220
# 99                          9990 DOUBLE R BLVD STE 200
# 100                        5067 MADRE MESA DR APT 2015
# 101                                1825 MONTE ALBAN DR
#
#     Provider Business Practice Location Address City Name  \
# 0                                            HENDERSON
# 1                                            LAS VEGAS
# 2                                            LAS VEGAS
# 3                                            LAS VEGAS
# 4                                          CARSON CITY
# ..                                                 ...
# 97                                              SPARKS
# 98                                         CARSON CITY
# 99                                                RENO
# 100                                          LAS VEGAS
# 101                                    NORTH LAS VEGAS
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   NV
# 1                                                   NV
# 2                                                   NV
# 3                                                   NV
# 4                                                   NV
# ..                                                 ...
# 97                                                  NV
# 98                                                  NV
# 99                                                  NV
# 100                                                 NV
# 101                                                 NV
#
#     Provider Business Practice Location Address Postal Code  \
# 0                                                89052
# 1                                                89109
# 2                                                89102
# 3                                                89148
# 4                                                89703
# ..                                                 ...
# 97                                               89434
# 98                                               89703
# 99                                               89521
# 100                                              89108
# 101                                              89031
#
#     Provider Business Practice Location Address Telephone Number
# 0                                           7029902290
# 1                                           7029921200
# 2                                           7029662414
# 3                                           7022621353
# 4                                           7758410660
# ..                                                 ...
# 97                                          7753488800
# 98                                          7753488800
# 99                                          7753488800
# 100                                         9032805025
# 101                                         8882374656
#
# [102 rows x 6 columns]

# %%
ph_tx_nv[ph_tx_nv['Provider Organization Name (Legal Business Name)'].str.contains("NORDSTROM")]
# Out:
#    Provider Organization Name (Legal Business Name)  \
# 27                     NORDSTROM INC & SUBSIDIARIES
#
#    Provider First Line Business Practice Location Address  \
# 27                      3200 LAS VEGAS BLVD S STE 710
#
#    Provider Business Practice Location Address City Name  \
# 27                                          LAS VEGAS
#
#    Provider Business Practice Location Address State Name  \
# 27                                                 NV
#
#    Provider Business Practice Location Address Postal Code  \
# 27                                              89109
#
#    Provider Business Practice Location Address Telephone Number
# 27                                         7028622525

# %%
l = ph_tx_nv[ph_tx_nv['Provider Organization Name (Legal Business Name)'].str.contains("PROSTHETICS") & ph_tx_nv['Provider Organization Name (Legal Business Name)'].str.contains("ORTHOTICS")]
len(l)
# Out:
# 21

# %% [markdown]
# ### Texas

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['222Z00000X', '224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# This defines the rows I want
def sub_rows(data):
    ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'TX'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    ac = data['NPI Deactivation Reason Code'].isna()
    all_together = ec & st & ta & ac 
    sub = data[all_together]
    return sub

def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )

ph_tx_tx = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)
ph_tx_tx['Provider Business Practice Location Address Postal Code'] = ph_tx_tx['Provider Business Practice Location Address Postal Code'].str[0:5]

ph_tx_tx = ph_tx_tx[['Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']]
ph_tx_tx
# Out:
# 2023-03-27 09:36:42.021007
# Grabbed iter 1 total sub n so far 55
# Grabbed iter 2 total sub n so far 188
# Grabbed iter 3 total sub n so far 282
# Grabbed iter 4 total sub n so far 360
# Grabbed iter 5 total sub n so far 441
# Grabbed iter 6 total sub n so far 570
# Grabbed iter 7 total sub n so far 665
# Grabbed iter 8 total sub n so far 746
# 2023-03-27 09:38:45.412652
#     Provider Organization Name (Legal Business Name)  \
# 0                          ASELAGE ORTHOTIC SERVICES
# 1                                       NIC DME, INC
# 2         SPORTS THERAPY AND REHABILITATION SERVICES
# 3                                  PARIS O & P, INC.
# 4                 HEDGECOCK ARTIFICIAL LIMB CO., INC
# ..                                               ...
# 741                                       OPA 1, LTD
# 742                                 NEMT MALEXIS LLC
# 743                         MAJOR MEDICAL SUPPLY INC
# 744                 INMOTION PROSTHETICS HOUSTON LLC
# 745                                 ALCHEMY WELLNESS
#
#     Provider First Line Business Practice Location Address  \
# 0                           1001 LOUISIANA AVE STE 304
# 1                                 3120 CENTER POINT DR
# 2                                 1555 MERRIMAC CIRCLE
# 3                               2619 NE LOOP 286 STE A
# 4                                   1917 S BECKHAM AVE
# ..                                                 ...
# 741                          5420 WEST LOOP S STE 1200
# 742                         8300 BISSONNET ST STE 460E
# 743                                      1700 W 2ND ST
# 744                       7324 SOUTHWEST FWY STE 2-885
# 745                           10501 QUAKER AVE STE 300
#
#     Provider Business Practice Location Address City Name  \
# 0                                       CORPUS CHRISTI
# 1                                             EDINBURG
# 2                                           FORT WORTH
# 3                                                PARIS
# 4                                                TYLER
# ..                                                 ...
# 741                                           BELLAIRE
# 742                                            HOUSTON
# 743                                             ODESSA
# 744                                            HOUSTON
# 745                                            LUBBOCK
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   TX
# 1                                                   TX
# 2                                                   TX
# 3                                                   TX
# 4                                                   TX
# ..                                                 ...
# 741                                                 TX
# 742                                                 TX
# 743                                                 TX
# 744                                                 TX
# 745                                                 TX
#
#     Provider Business Practice Location Address Postal Code  \
# 0                                                78404
# 1                                                78539
# 2                                                76107
# 3                                                75460
# 4                                                75701
# ..                                                 ...
# 741                                              77401
# 742                                              77074
# 743                                              79763
# 744                                              77074
# 745                                              79424
#
#     Provider Business Practice Location Address Telephone Number
# 0                                           3618542355
# 1                                           9569949424
# 2                                           8178704949
# 3                                           9037858922
# 4                                           9035312228
# ..                                                 ...
# 741                                         7136608801
# 742                                         7133915035
# 743                                         4323323621
# 744                                         8325812324
# 745                                         8063707311
#
# [746 rows x 6 columns]

# %%
l = ph_tx_tx[ph_tx_tx['Provider Organization Name (Legal Business Name)'].str.contains("PROSTHETICS") & ph_tx_tx['Provider Organization Name (Legal Business Name)'].str.contains("ORTHOTICS")]
len(l)
# Out:
# 124

# %% [markdown]
# ### Washington

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['222Z00000X', '224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# This defines the rows I want
def sub_rows(data):
    ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'WA'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    ac = data['NPI Deactivation Reason Code'].isna()
    all_together = ec & st & ta & ac 
    sub = data[all_together]
    return sub

def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )

ph_tx_wa = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)
ph_tx_wa['Provider Business Practice Location Address Postal Code'] = ph_tx_wa['Provider Business Practice Location Address Postal Code'].str[0:5]

ph_tx_wa = ph_tx_wa[['Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']]
ph_tx_wa
# Out:
# 2023-03-27 09:46:51.924525
# Grabbed iter 1 total sub n so far 15
# Grabbed iter 2 total sub n so far 54
# Grabbed iter 3 total sub n so far 92
# Grabbed iter 4 total sub n so far 107
# Grabbed iter 5 total sub n so far 126
# Grabbed iter 6 total sub n so far 153
# Grabbed iter 7 total sub n so far 191
# Grabbed iter 8 total sub n so far 205
# 2023-03-27 09:48:54.115012
#     Provider Organization Name (Legal Business Name)  \
# 0             CENTER FOR PROSTHETICS ORTHOTICS, INC.
# 1             CENTER FOR PROSTHETICS ORTHOTICS, INC.
# 2            MASTER'S ORTHOTICS AND PROSTHETICS, LLC
# 3            CASCADE PROSTHETICS AND ORTHOTICS, INC.
# 4                              BOND ENTERPRISES INC.
# ..                                               ...
# 200  INLAND NORTHWEST ORTHOTICS AND PROSTHETICS, INC
# 201                            DISCREET SUPPLIES LLC
# 202                                     JANALAIR LLC
# 203                                     JANALAIR LLC
# 204                           THOME ENTERPRISE L L C
#
#     Provider First Line Business Practice Location Address  \
# 0                                         411 12TH AVE
# 1                                         411 12TH AVE
# 2                             4409 NW ANDERSON HILL RD
# 3                                      17670 DUNBAR RD
# 4                             4700 POINT FOSDICK DR NW
# ..                                                 ...
# 200                                         717 6TH ST
# 201                      5215 W CLEARWATER AVE STE 106
# 202                              7942 NOBLE VIEW LN NW
# 203                              7942 NOBLE VIEW LN NW
# 204                                      119 E 3RD AVE
#
#     Provider Business Practice Location Address City Name  \
# 0                                              SEATTLE
# 1                                              SEATTLE
# 2                                           SILVERDALE
# 3                                         MOUNT VERNON
# 4                                           GIG HARBOR
# ..                                                 ...
# 200                                          CLARKSTON
# 201                                          KENNEWICK
# 202                                            OLYMPIA
# 203                                            OLYMPIA
# 204                                              SELAH
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   WA
# 1                                                   WA
# 2                                                   WA
# 3                                                   WA
# 4                                                   WA
# ..                                                 ...
# 200                                                 WA
# 201                                                 WA
# 202                                                 WA
# 203                                                 WA
# 204                                                 WA
#
#     Provider Business Practice Location Address Postal Code  \
# 0                                                98122
# 1                                                98122
# 2                                                98383
# 3                                                98273
# 4                                                98335
# ..                                                 ...
# 200                                              99403
# 201                                              99336
# 202                                              98502
# 203                                              98502
# 204                                              98942
#
#     Provider Business Practice Location Address Telephone Number
# 0                                           2063284276
# 1                                           2063284276
# 2                                           3606986020
# 3                                           3604284003
# 4                                           2538589941
# ..                                                 ...
# 200                                         5097588874
# 201                                         5094913266
# 202                                         3607912207
# 203                                         3607912207
# 204                                         5096976125
#
# [205 rows x 6 columns]

# %%
l = ph_tx_wa[ph_tx_wa['Provider Organization Name (Legal Business Name)'].str.contains("PROSTHETICS") & ph_tx_wa['Provider Organization Name (Legal Business Name)'].str.contains("ORTHOTICS")]
len(l)
# Out:
# 58

# %% [markdown]
# ### Oregon

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['222Z00000X', '224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# This defines the rows I want
def sub_rows(data):
    ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'OR'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    ac = data['NPI Deactivation Reason Code'].isna()
    all_together = ec & st & ta & ac 
    sub = data[all_together]
    return sub

def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )

ph_tx_or = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)
ph_tx_or['Provider Business Practice Location Address Postal Code'] = ph_tx_or['Provider Business Practice Location Address Postal Code'].str[0:5]

ph_tx_or = ph_tx_or[['Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']]
ph_tx_or
# Out:
# 2023-03-27 09:48:54.126232
# Grabbed iter 1 total sub n so far 3
# Grabbed iter 2 total sub n so far 22
# Grabbed iter 3 total sub n so far 47
# Grabbed iter 4 total sub n so far 62
# Grabbed iter 5 total sub n so far 78
# Grabbed iter 6 total sub n so far 90
# Grabbed iter 7 total sub n so far 113
# Grabbed iter 8 total sub n so far 124
# 2023-03-27 09:50:57.808975
#     Provider Organization Name (Legal Business Name)  \
# 0                                       FOOT FITNESS
# 1                               PARADOX WALKFIT INC.
# 2            HANGER PROSTHETICS & ORTHOTICS WEST INC
# 3                 HANGER PROSTHETICS & ORTHOTICS INC
# 4                      SYNERGY MEDICAL SYSTEMS, INC.
# ..                                               ...
# 119          SPECTRUM PROSTHETICS AND ORTHOTICS, LLC
# 120             SPECTRUM ORTHOTICS & PROSTHETICS INC
# 121                                         KRFS LLC
# 122                         SPECTRUM PROSTHETICS LLC
# 123                                      R C P S INC
#
#     Provider First Line Business Practice Location Address  \
# 0                                  258 SW 5TH ST STE 2
# 1                                 15532 SW PACIFIC HWY
# 2                                       341 SE 3RD AVE
# 3                                   2275 NE DOCTORS DR
# 4                                 1245 RHODODENDRON DR
# ..                                                 ...
# 119                                300 UNION AVE STE C
# 120                                  3541 E BARNETT RD
# 121                                2231 N ELDORADO AVE
# 122                                   1963 THOMPSON RD
# 123                            2594 E BARNETT RD STE D
#
#     Provider Business Practice Location Address City Name  \
# 0                                              REDMOND
# 1                                               TIGARD
# 2                                            HILLSBORO
# 3                                                 BEND
# 4                                             FLORENCE
# ..                                                 ...
# 119                                        GRANTS PASS
# 120                                            MEDFORD
# 121                                      KLAMATH FALLS
# 122                                           COOS BAY
# 123                                            MEDFORD
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   OR
# 1                                                   OR
# 2                                                   OR
# 3                                                   OR
# 4                                                   OR
# ..                                                 ...
# 119                                                 OR
# 120                                                 OR
# 121                                                 OR
# 122                                                 OR
# 123                                                 OR
#
#     Provider Business Practice Location Address Postal Code  \
# 0                                                97756
# 1                                                97224
# 2                                                97123
# 3                                                97701
# 4                                                97439
# ..                                                 ...
# 119                                              97527
# 120                                              97504
# 121                                              97601
# 122                                              97420
# 123                                              97504
#
#     Provider Business Practice Location Address Telephone Number
# 0                                           5419232552
# 1                                           5036246400
# 2                                           5036408477
# 3                                           5413890633
# 4                                           5419974134
# ..                                                 ...
# 119                                         5419559678
# 120                                         5417342435
# 121                                         5418845348
# 122                                         5412691773
# 123                                         4582258233
#
# [124 rows x 6 columns]

# %%
l = ph_tx_or[ph_tx_or['Provider Organization Name (Legal Business Name)'].str.contains("PROSTHETICS") & ph_tx_or['Provider Organization Name (Legal Business Name)'].str.contains("ORTHOTICS")]
len(l)
# Out:
# 43

# %% [markdown]
# ### Illinois

# %%
taxon_codes = ['Healthcare Provider Taxonomy Code_' + str(i+1) for i in range(15)]
keep_col += taxon_codes
community_pharm = ['222Z00000X', '224P00000X','335E00000X']
npi_csv = 'npidata_pfile_20050523-20230212.csv' #Newer files will prob change the name

# This defines the rows I want
def sub_rows(data):
    ec = data['Entity Type Code'] == "2"
    st = data['Provider Business Practice Location Address State Name'] == 'IL'
    ta = data[taxon_codes].isin(community_pharm).any(axis=1)
    ac = data['NPI Deactivation Reason Code'].isna()
    all_together = ec & st & ta & ac 
    sub = data[all_together]
    return sub

def csv_chunks(file,chunk_size,keep_cols,row_sub):
    # First lets get the header and figure out the column indices
    header_fields = list(pd.read_csv(npi_csv, nrows=1))
    header_locs = [header_fields.index(i) for i in keep_cols]
    # Now reading in a chunk of data
    skip = 1
    it_n = 0
    sub_n = 0
    ret_chunk = chunk_size
    fin_li_dat = []
    while ret_chunk == chunk_size:
        file_chunk = pd.read_csv(file, usecols=header_locs, skiprows=skip, 
                     nrows=chunk_size, names=header_fields, dtype='str')
        sub_dat = row_sub(file_chunk)
        fin_li_dat.append( sub_dat.copy() )
        skip += chunk_size
        it_n += 1
        sub_n += sub_dat.shape[0]
        print(f'Grabbed iter {it_n} total sub n so far {sub_n}')
        ret_chunk = file_chunk.shape[0]
    fin_dat = pd.concat(fin_li_dat, axis=0)
    return fin_dat

# Takes about 3 minutes
print( datetime.now() )
pharm_tx = csv_chunks(npi_csv, chunk_size=1000000, keep_cols=keep_col, row_sub=sub_rows)
print( datetime.now() )

ph_tx_il = pharm_tx.drop(columns=taxon_codes).reset_index(drop=True)
ph_tx_il['Provider Business Practice Location Address Postal Code'] = ph_tx_il['Provider Business Practice Location Address Postal Code'].str[0:5]

ph_tx_il = ph_tx_il[['Provider Organization Name (Legal Business Name)',
            'Provider First Line Business Practice Location Address',
            'Provider Business Practice Location Address City Name',
            'Provider Business Practice Location Address State Name',
            'Provider Business Practice Location Address Postal Code',
            'Provider Business Practice Location Address Telephone Number']]
ph_tx_il
# Out:
# 2023-03-27 09:40:17.150540
# Grabbed iter 1 total sub n so far 29
# Grabbed iter 2 total sub n so far 82
# Grabbed iter 3 total sub n so far 114
# Grabbed iter 4 total sub n so far 137
# Grabbed iter 5 total sub n so far 190
# Grabbed iter 6 total sub n so far 263
# Grabbed iter 7 total sub n so far 329
# Grabbed iter 8 total sub n so far 352
# 2023-03-27 09:42:22.533302
#       Provider Organization Name (Legal Business Name)  \
# 0                                  BEAUTY IMAGE CENTER
# 1                                AGONY OF DE-FEET LTD.
# 2    ANTOINETTE'S WIGS & DAISY BOUTIQUE MASTECTOMY ...
# 3                    NATIONAL PEDORTHIC SERVICES, INC.
# 4                                   WEIBEL ENTERPRISES
# ..                                                 ...
# 347                          GLENN REAMS OCULARIST INC
# 348                                PSI HEALTH CARE INC
# 349                               SYNAPSE HEALTH, INC.
# 350                       SALUBRIOUS INTERNATIONAL LLC
# 351                       SALUBRIOUS INTERNATIONAL LLC
#
#     Provider First Line Business Practice Location Address  \
# 0                                      1280 BAMBERG CT
# 1                                 1324 S MILWAUKEE AVE
# 2                                        4714 147TH ST
# 3                               4804 S STATE ROUTE 159
# 4                                   1012 S ELMHURST RD
# ..                                                 ...
# 347                               111 S MAIN ST STE 2F
# 348                                1515 46TH AVE STE 1
# 349                       1603 ORRINGTON AVE STE LL004
# 350                                      359 E 79TH ST
# 351                                      359 E 79TH ST
#
#     Provider Business Practice Location Address City Name  \
# 0                                         HANOVER PARK
# 1                                         LIBERTYVILLE
# 2                                           MIDLOTHIAN
# 3                                          GLEN CARBON
# 4                                       MOUNT PROSPECT
# ..                                                 ...
# 347                                           WATERLOO
# 348                                             MOLINE
# 349                                           EVANSTON
# 350                                            CHICAGO
# 351                                            CHICAGO
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   IL
# 1                                                   IL
# 2                                                   IL
# 3                                                   IL
# 4                                                   IL
# ..                                                 ...
# 347                                                 IL
# 348                                                 IL
# 349                                                 IL
# 350                                                 IL
# 351                                                 IL
#
#     Provider Business Practice Location Address Postal Code  \
# 0                                                60103
# 1                                                60048
# 2                                                60445
# 3                                                62034
# 4                                                60056
# ..                                                 ...
# 347                                              62298
# 348                                              61265
# 349                                              60201
# 350                                              60619
# 351                                              60619
#
#     Provider Business Practice Location Address Telephone Number
# 0                                           6304839225
# 1                                           8476807534
# 2                                           7083855736
# 3                                           4144381211
# 4                                           8477180587
# ..                                                 ...
# 347                                         6189397577
# 348                                         5633593556
# 349                                         8477374455
# 350                                         7734690386
# 351                                         7734690386
#
# [352 rows x 6 columns]

# %%
l = ph_tx_il[ph_tx_az['Provider Organization Name (Legal Business Name)'].str.contains("PROSTHETICS") & ph_tx_il['Provider Organization Name (Legal Business Name)'].str.contains("ORTHOTICS")]
len(l)
# Out:
# 19
